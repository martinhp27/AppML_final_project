# %%
# Import standard libraries:
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("darkgrid")
import pandas as pd

import glob
from PIL import Image

MetaData = pd.read_csv("./train/train.csv")

# %%
NoP = 2000

# %%
MetaPath = ["camp.csv","corylus.csv","dust.csv","grim.csv","qrob.csv","qsub.csv"]

MetaData = []
todrop = ['Particle ID',
          'Calibration Factor',
          'Calibration Image',
          'Camera',
          'Capture X',
          'Capture Y',
          'Date',
          'Elapsed Time',
          'Filter Score',
          'Image File',
          'Image Height',
          'Image Width',
          'Image X',
          'Image Y',
          'Source Image',
          'Time',
          'Timestamp',
          'imgpaths',
          'Sample'
         ]
for i in range(len(MetaPath)):
    Data = pd.read_csv("./train/{}".format(MetaPath[i]))
    Data = Data.drop(columns = todrop)
    Data = Data[:NoP]
    MetaData.append(Data.to_numpy())

# %%
Data
# Out:
#       Area (ABD)  Area (Filled)  Aspect Ratio  Biovolume (Cylinder)  \
# 0         885.10         887.08          0.93              19273.96
# 1         377.32         377.32          0.47               4527.90
# 2         941.16         941.16          0.98              20719.24
# 3         327.45         347.82          0.57               2962.84
# 4         714.22         714.22          0.89              13950.09
# ...          ...            ...           ...                   ...
# 1995     1071.23        1071.23          0.91              28225.35
# 1996      803.22         805.34          0.90              18343.96
# 1997     1009.78        1011.32          0.87              11611.33
# 1998     1155.56        1188.28          0.88              17873.73
# 1999      809.64         810.81          0.90              14069.18
#
#       Biovolume (P. Spheroid)  Biovolume (Sphere)  Circle Fit  Circularity  \
# 0                    19160.81            19808.64        0.81         0.76
# 1                     3983.04             5513.53        0.22         0.67
# 2                    21556.88            21719.82        0.95         0.89
# 3                     4360.78             4457.41        0.13         0.49
# 4                    13557.22            14358.65        0.87         0.89
# ...                       ...                 ...         ...          ...
# 1995                 25203.05            26374.88        0.85         0.83
# 1996                 16320.23            17124.49        0.87         0.84
# 1997                 22872.73            24138.28        0.31         0.39
# 1998                 29707.89            29549.50        0.52         0.51
# 1999                 16687.48            17330.10        0.68         0.69
#
#       Circularity (Hu)  Compactness  ...  Sphere Complement  Sphere Count  \
# 0                 0.99         1.32  ...               0.26             1
# 1                 0.73         1.49  ...               0.00             2
# 2                 1.00         1.12  ...               0.00             1
# 3                 0.76         2.04  ...               0.00             6
# 4                 0.99         1.12  ...               0.00             1
# ...                ...          ...  ...                ...           ...
# 1995              0.99         1.21  ...               0.00             1
# 1996              0.99         1.20  ...               0.00             1
# 1997              0.98         2.54  ...               0.00             1
# 1998              0.98         1.96  ...               0.00             4
# 1999              0.99         1.45  ...               0.00             1
#
#       Sphere Unknown  Sphere Volume  Sum Intensity  Symmetry  Transparency  \
# 0                0.0       19345.45       774132.0      0.80          0.02
# 1                0.0        5512.32       299029.0      0.61          0.17
# 2                0.0       22014.73       579055.0      0.95          0.01
# 3                0.0        4980.55       354478.0      0.32          0.19
# 4                0.0       15264.67       578220.0      0.95          0.01
# ...              ...            ...            ...       ...           ...
# 1995             0.0       32289.23       689200.0      0.90          0.02
# 1996             0.0       15100.71       661906.0      0.92          0.02
# 1997             0.0       23207.68       824899.0      0.55          0.04
# 1998             0.0       20666.54       934982.0      0.59          0.05
# 1999             0.0       16423.58       727762.0      0.66          0.03
#
#       Volume (ABD)  Volume (ESD)  Width
# 0        19808.640     21233.510  32.42
# 1         5513.528      9665.368  14.17
# 2        21719.820     22304.890  34.26
# 3         4457.412      8376.249  17.48
# 4        14358.650     14897.100  28.81
# ...            ...           ...    ...
# 1995     26374.880     27883.940  35.76
# 1996     17124.490     18232.660  31.07
# 1997     24138.280     27300.960  34.06
# 1998     29549.500     34725.640  37.67
# 1999     17330.100     18744.450  31.32
#
# [2000 rows x 39 columns]

# %%
N = 256

path = ["campanian","corylus","dust","grimsvotn","qrobur","qsuber"]

files1 = glob.glob('train/'+path[0]+'/*.png')
files1 = files1[:NoP]
data_camp = np.zeros((len(files1),N,N), dtype=np.uint8)
for i in range(len(files1)):
    im = Image.open(files1[i]).resize((N,N))
    data_camp[i] = np.asarray(im, dtype=np.uint8)

# %%
files2 = glob.glob('train/'+path[1]+'/*.png')
files2 = files2[:NoP]
data_cory = np.zeros((len(files2),N,N), dtype=np.uint8)
for i in range(len(files2)):
    im = Image.open(files2[i]).resize((N,N))
    data_cory[i] = np.asarray(im, dtype=np.uint8)

# %%
files3 = glob.glob('train/'+path[2]+'/*.png')
files3 = files3[:NoP]
data_dust = np.zeros((len(files3),N,N), dtype=np.uint8)
for i in range(len(files3)):
    im = Image.open(files3[i]).resize((N,N))
    data_dust[i] = np.asarray(im,dtype=np.uint8)

# %%
files4 = glob.glob('train/'+path[3]+'/*.png')
files4 = files4[:NoP]
data_grim = np.zeros((len(files4),N,N),dtype=np.uint8)
for i in range(len(files4)):
    im = Image.open(files4[i]).resize((N,N), )
    data_grim[i] = np.asarray(im, dtype=np.uint8)

# %%
files5 = glob.glob('train/'+path[4]+'/*.png')
files5 = files5[:NoP]
data_qro = np.zeros((len(files5),N,N), dtype=np.uint8)
for i in range(len(files5)):
    im = Image.open(files5[i]).resize((N,N))
    data_qro[i] = np.asarray(im, dtype=np.uint8)

# %%
files6 = glob.glob('train/'+path[5]+'/*.png')
files6 = files6[:NoP]
data_qsu = np.zeros((len(files6),N,N), dtype=np.uint8)
for i in range(len(files6)):
    im = Image.open(files6[i]).resize((N,N))
    data_qsu[i] = np.asarray(im, dtype=np.uint8)

# %%
n = 0
path = ["campanian","corylus","dust","grimsvotn","qrobur","qsuber"]
for i in path:
    n += len(glob.glob('train/'+i+'/*.png'))

# %%
data = np.vstack((data_camp, data_cory, data_dust, data_grim, data_qro, data_qsu))
meta = np.vstack(( MetaData[0], MetaData[1], MetaData[2], MetaData[3], MetaData[4], MetaData[5] ))

label = []
for j in range(6):
    label += [j for i in range(NoP)]
label = np.array(label)    

np.savez_compressed('data+meta.npz', data=data, label=label, meta = meta)

# %%
data_ash = np.vstack((data_camp, data_grim)) 
metadata_ash = np.vstack(( MetaData[0], MetaData[3] ))


data_pollen = np.vstack((data_cory, data_qro, data_qsu))
metadata_pollen = np.vstack(( MetaData[1], MetaData[4], MetaData[5] ))

files = files1+files2+files3+files4+files5+files6


names = []

for i in range(len(path)):
    for n in range(len(files)):
        names.append(path[i]+str(n))

label_ash = np.concatenate((np.zeros((1,500)), np.ones((1,500))), axis=1)  
label_pollen = np.concatenate((np.zeros((1,500)), np.ones((1,500)), np.full((1,500), 2)), axis=1)

#mapping = dict(names)
        

np.savez_compressed('data_codingset_ash.npz', data_ash=data_ash, label=label_ash, metadata_ash = metadata_ash)
np.savez_compressed('data_codingset_pollen.npz', data_pollen=data_pollen, label=label_pollen, metadata_pollen = metadata_pollen )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e4d8ff270952> in <module>
# ----> 1 data = np.vstack((data_camp, data_cory, data_dust, data_grim, data_qro, data_qsu))
#       2 meta = np.vstack(( MetaData[0], MetaData[3] ))
#       3
#       4
#       5 data_ash = np.vstack((data_camp, data_grim))
#
# NameError: name 'np' is not defined

# %%
metadata_ash.shape
# Out:
# (1000, 39)

# %%
data_ash.shape
# Out:
# (1000, 256, 256)

# %%
label_ash.shape
# Out:
# (1, 1000)
