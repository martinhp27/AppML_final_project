# %% [markdown]
# ### Important packages

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
# General packages
import sys
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import Series, DataFrame 
import h5py
import seaborn as sns
import tensorflow as tf

# Numerical packages
import matplotlib
import sklearn
import itertools
from tqdm import tqdm
from scipy import stats, integrate
from scipy.optimize import curve_fit
import scipy.constants as const
from numpy.linalg import inv

# # Import KDE
# from sklearn.neighbors import KernelDensity

# # MCMC
# import emcee

# # Splines
# from scipy.interpolate import interp1d, BSpline, PchipInterpolator
# #from csaps import csaps

# # Nested sampling
# import nestle

# Boosted decision tree packages
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
# import lightgbm as lgb 
# import xgboost as xgb 
from sklearn.metrics import accuracy_score, auc
from sklearn.metrics import mean_squared_error
#import shap

# Neural network
from keras.models import Sequential
from keras.layers import Dense
import keras
from sklearn.inspection import permutation_importance
from keras.layers.core import Dense, Dropout, Flatten
from keras.optimizers import SGD
from keras.layers import Dropout
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.losses import categorical_crossentropy
from keras.optimizers import Adadelta
import tensorflow as tf

#tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# # Random Forets
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.ensemble import ExtraTreesClassifier
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.model_selection import cross_val_score # for cross-validation


# # Baysian optimization 

#from bayes_opt import BayesianOptimization


# # Random search
# from sklearn.model_selection import RandomizedSearchCV, KFold

# # Data preprocessing 
from sklearn.preprocessing import LabelEncoder,OneHotEncoder, StandardScaler
from datetime import datetime 
import time

# # Fit og plot packages
# from iminuit import Minuit
# # sys.path.append('C:/Users/marti/Google Drev/Uni/Pyhton/External_Functions')
# # from ExternalFunctions import Chi2Regression, BinnedLH, UnbinnedLH
# # from ExternalFunctions import nice_string_output, add_text_to_ax    # Useful functions to print fit results on figure

# %%
# !pip install bayesian-optimization
# Out:
# Requirement already satisfied: bayesian-optimization in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Requirement already satisfied: scikit-learn>=0.18.0 in /usr/local/lib/python3.7/dist-packages (from bayesian-optimization) (0.22.2.post1)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from bayesian-optimization) (1.19.5)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from bayesian-optimization) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.18.0->bayesian-optimization) (1.0.1)

# %% [markdown]
# ### Pretty plotting routines

# %%
def reset_plt(ticksize,fontsize):
    plt.style.use('seaborn-white')
    plt.rcParams['xtick.labelsize'] = ticksize
    plt.rcParams['ytick.labelsize'] = ticksize
    plt.rcParams['font.size'] = fontsize
    plt.rcParams['mathtext.fontset'] = 'stix'
    plt.rcParams['font.family'] = 'STIXGeneral'
    plt.rcParams['legend.facecolor'] = 'white'
    #plt.rcParams['axes.formatter.limits'] = (-1,3)
    #plt.rcParams['axes.linewidth'] = 2.25
    

def put_ticks(this_fig,this_ax):
    this_ax.xaxis.set_tick_params(which = 'major', direction = 'in', width = 2.5, length = 12, zorder = 1, top = True)
    this_ax.yaxis.set_tick_params(which = 'major', direction = 'in', width = 2.5, length = 12, zorder = 1, right = True)
    this_ax.xaxis.set_tick_params(which = 'minor', direction = 'in', width = 1.5, length = 6, zorder = 1, top = True)
    this_ax.yaxis.set_tick_params(which = 'minor', direction = 'in', width = 1.5, length = 6, zorder = 1, right = True)
    dx = -3/72
    dy = -3/72
    y_offset = matplotlib.transforms.ScaledTranslation(0, dy, this_fig.dpi_scale_trans)
    x_offset = matplotlib.transforms.ScaledTranslation(dx, 0, this_fig.dpi_scale_trans)

    for label in this_ax.xaxis.get_majorticklabels():
        label.set_transform(label.get_transform() + y_offset)

    for label in this_ax.yaxis.get_majorticklabels():
        label.set_transform(label.get_transform() + x_offset)

# %% [markdown]
# ### Import data

# %%
data_ash = np.load('/content/drive/MyDrive/ColabNotebooks/data_codingset_ash.npz') # label 0
data_pollen = np.load('/content/drive/MyDrive/ColabNotebooks/data_codingset_pollen.npz') # label 1
data_dust = np.load('/content/drive/MyDrive/ColabNotebooks/data_codingset_dust.npz') # label 2

data = np.concatenate((data_ash['data_ash'],data_pollen['data_pollen'],data_dust['data_dust']))
labels = np.concatenate((data_ash['label'],data_pollen['label'],data_dust['label']), axis=1)[0]
labels.shape, data.shape
# Out:
# ((3000,), (3000, 256, 256))

# %% [markdown]
# ### Scale data and separate it into train, val and test

# %%
# Split the data set and labels into train, validation and test set
test_size = 0.2
val_size = 0.2

train_val_images,test_images,train_val_labels,test_labels = train_test_split(data
                                               ,labels,test_size=test_size, random_state=42)
train_images,val_images,train_labels,val_labels = train_test_split(train_val_images,train_val_labels,test_size=val_size, random_state=42)

# explicitly illustrating standardization
def standardizeimg(img, mu, sigma):
    return (img-mu)/(sigma).astype(np.float32)

# save for scaling test data
mu_train = np.mean(train_images)
sigma_train = np.std(train_images)

# Standardize pixel distribution to have zero mean and unit variance
train_images = standardizeimg(img=train_images, mu=mu_train, sigma=sigma_train)
val_images = standardizeimg(img=val_images, mu=np.mean(val_images), sigma=np.std(val_images))


# adapt to format required by tensorflow; Using channels_last --> (n_samples, img_rows, img_cols, n_channels)
img_rows, img_cols = 256, 256 # input image dimensions
train_images = train_images.reshape(train_images.shape[0], img_rows, img_cols, 1)
val_images = val_images.reshape(val_images.shape[0], img_rows, img_cols, 1)

# convert class vectors to binary class matrices - one hot encoding
num_classes = 3
train_labels = tf.keras.utils.to_categorical(train_labels, num_classes)
val_labels = tf.keras.utils.to_categorical(val_labels, num_classes)

# avoid using statistics intrinsic to test data to ensure unbiased estimate of real model performance
test_images = standardizeimg(img=test_images, mu=mu_train, sigma=sigma_train)
test_images = test_images.reshape(test_images.shape[0], img_rows, img_cols, 1)
test_labels = tf.keras.utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# ### Inspect data

# %%
print("Training set:")
print(" > images:", train_images.shape)
print(" > labels:", train_labels.shape)
print("Validation set:")
print(" > images:", val_images.shape)
print(" > labels:", val_labels.shape)
print("Test set:")
print(" > images:", test_images.shape)
print(" > labels:", test_labels.shape)
# Out:
# Training set:
#  > images: (1920, 256, 256, 1)
#  > labels: (1920, 3)
# Validation set:
#  > images: (480, 256, 256, 1)
#  > labels: (480, 3)
# Test set:
#  > images: (600, 256, 256, 1)
#  > labels: (600, 3)

# %%
import tensorflow 
tensorflow.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
fig, ax = plt.subplots(nrows=3, ncols=5, figsize=(10,6))
for i in range(5):

    # train
    ax[0,i].imshow(train_images[i].reshape(img_rows, img_cols), cmap=plt.cm.binary)
    ax[0,i].set_xlabel(np.argmax(train_labels[i]), fontsize=18)
    ax[0,i].set_xticks([]); ax[0,i].set_yticks([]); ax[0,i].grid(False)
    # val
    ax[1,i].imshow(val_images[i].reshape(img_rows, img_cols), cmap=plt.cm.binary)
    ax[1,i].set_xlabel(np.argmax(val_labels[i]), fontsize=18)
    ax[1,i].set_xticks([]); ax[1,i].set_yticks([]); ax[1,i].grid(False)
    # test
    ax[2,i].imshow(test_images[i].reshape(img_rows, img_cols), cmap=plt.cm.binary)
    ax[2,i].set_xlabel(np.argmax(test_labels[i]), fontsize=18)
    ax[2,i].set_xticks([]); ax[2,i].set_yticks([]); ax[2,i].grid(False)
    
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(16,4))
ax[0].hist(np.argmax(train_labels, axis=1).flatten()); ax[0].set_title('train', fontsize=18); ax[0].set_xticks(np.arange(num_classes)); ax[0].tick_params(axis='both', which='major', labelsize=16);
ax[1].hist(np.argmax(val_labels, axis=1).flatten()); ax[1].set_title('validation', fontsize=18); ax[1].set_xticks(np.arange(num_classes)); ax[1].tick_params(axis='both', which='major', labelsize=16);
ax[2].hist(np.argmax(test_labels, axis=1).flatten()); ax[2].set_title('test', fontsize=18); ax[2].set_xticks(np.arange(num_classes)); ax[2].tick_params(axis='both', which='major', labelsize=16);
plt.show()

# %% [markdown]
# ### Create the CNN

# %%
model = Sequential()
# This layer creates a convolution kernel that is convolved with the layer input 
# to produce a tensor of outputs.
# When using this l
# Layer as the first layer in a model, provide the keyword argument
# input_shape
# Same in padding means zero padding evenly to left/right and up/down 
model.add(Conv2D(filters=32,
                 kernel_size=3,
                 strides=1,
                 padding='same',
                 activation='relu',
                 input_shape=(img_rows, img_cols, 1)))
# Downsamples the input along its spatial dimensions (height and width) by taking
# the maximum value over an input window (of size defined by pool_size) for each
# channel of the input. The window is shifted by strides along each dimension.
model.add(MaxPooling2D(pool_size=2, strides=None))

model.add(Conv2D(filters=64,
                 kernel_size=3,
                 strides=1,
                 padding='same',
                 activation='relu'))

model.add(MaxPooling2D(pool_size=2, strides=None))

model.add(Dropout(rate=0.40))

model.add(Flatten())



model.add(Dense(units=128, activation='relu'))

model.add(Dense(units=num_classes, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 262144)            0
# _________________________________________________________________
# dense (Dense)                (None, 128)               33554560
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 33,573,763
# Trainable params: 33,573,763
# Non-trainable params: 0
# _________________________________________________________________

# %%
# specify optimization strategy and metric used for monitoring during training
model.compile(loss=categorical_crossentropy,
              optimizer=tf.keras.optimizers.Adam(learning_rate= 0.00001),
              metrics=['categorical_accuracy'])

# the history object will contain a record of loss and metric values during training
history = model.fit(train_images, train_labels,
                    batch_size=128,
                    epochs=60,
                    verbose=1,
                    validation_data=(val_images, val_labels))
# Out:
# Epoch 1/60
# 15/15 [==============================] - 21s 325ms/step - loss: 0.9126 - categorical_accuracy: 0.5145 - val_loss: 0.5878 - val_categorical_accuracy: 0.7500
# Epoch 2/60
# 15/15 [==============================] - 3s 222ms/step - loss: 0.5341 - categorical_accuracy: 0.7977 - val_loss: 0.5039 - val_categorical_accuracy: 0.8167
# Epoch 3/60
# 15/15 [==============================] - 3s 222ms/step - loss: 0.4465 - categorical_accuracy: 0.8394 - val_loss: 0.4315 - val_categorical_accuracy: 0.8292
# Epoch 4/60
# 15/15 [==============================] - 3s 223ms/step - loss: 0.4149 - categorical_accuracy: 0.8438 - val_loss: 0.4097 - val_categorical_accuracy: 0.8271
# Epoch 5/60
# 15/15 [==============================] - 3s 223ms/step - loss: 0.3646 - categorical_accuracy: 0.8587 - val_loss: 0.3962 - val_categorical_accuracy: 0.8375
# Epoch 6/60
# 15/15 [==============================] - 3s 224ms/step - loss: 0.3345 - categorical_accuracy: 0.8801 - val_loss: 0.3841 - val_categorical_accuracy: 0.8521
# Epoch 7/60
# 15/15 [==============================] - 3s 223ms/step - loss: 0.3236 - categorical_accuracy: 0.8775 - val_loss: 0.3736 - val_categorical_accuracy: 0.8687
# Epoch 8/60
# 15/15 [==============================] - 3s 221ms/step - loss: 0.3275 - categorical_accuracy: 0.8803 - val_loss: 0.3617 - val_categorical_accuracy: 0.8625
# Epoch 9/60
# 15/15 [==============================] - 3s 223ms/step - loss: 0.3004 - categorical_accuracy: 0.8929 - val_loss: 0.3483 - val_categorical_accuracy: 0.8729
# Epoch 10/60
# 15/15 [==============================] - 3s 222ms/step - loss: 0.2828 - categorical_accuracy: 0.9056 - val_loss: 0.3425 - val_categorical_accuracy: 0.8813
# Epoch 11/60
# 15/15 [==============================] - 3s 218ms/step - loss: 0.2798 - categorical_accuracy: 0.9035 - val_loss: 0.3407 - val_categorical_accuracy: 0.8729
# Epoch 12/60
# 15/15 [==============================] - 3s 221ms/step - loss: 0.2636 - categorical_accuracy: 0.9203 - val_loss: 0.3329 - val_categorical_accuracy: 0.8833
# Epoch 13/60
# 15/15 [==============================] - 3s 220ms/step - loss: 0.2424 - categorical_accuracy: 0.9142 - val_loss: 0.3344 - val_categorical_accuracy: 0.8792
# Epoch 14/60
# 15/15 [==============================] - 3s 223ms/step - loss: 0.2396 - categorical_accuracy: 0.9100 - val_loss: 0.3381 - val_categorical_accuracy: 0.8958
# Epoch 15/60
# 15/15 [==============================] - 3s 219ms/step - loss: 0.2300 - categorical_accuracy: 0.9262 - val_loss: 0.3228 - val_categorical_accuracy: 0.8958
# Epoch 16/60
# 15/15 [==============================] - 3s 217ms/step - loss: 0.2173 - categorical_accuracy: 0.9250 - val_loss: 0.3152 - val_categorical_accuracy: 0.8958
# Epoch 17/60
# 15/15 [==============================] - 3s 218ms/step - loss: 0.2125 - categorical_accuracy: 0.9284 - val_loss: 0.3253 - val_categorical_accuracy: 0.8958
# Epoch 18/60
# 15/15 [==============================] - 3s 218ms/step - loss: 0.1989 - categorical_accuracy: 0.9348 - val_loss: 0.3095 - val_categorical_accuracy: 0.9042
# Epoch 19/60
# 15/15 [==============================] - 3s 218ms/step - loss: 0.1979 - categorical_accuracy: 0.9309 - val_loss: 0.3162 - val_categorical_accuracy: 0.9042
# Epoch 20/60
# 15/15 [==============================] - 3s 217ms/step - loss: 0.1922 - categorical_accuracy: 0.9400 - val_loss: 0.3197 - val_categorical_accuracy: 0.8833
# Epoch 21/60
# 15/15 [==============================] - 3s 218ms/step - loss: 0.1943 - categorical_accuracy: 0.9319 - val_loss: 0.2989 - val_categorical_accuracy: 0.9021
# Epoch 22/60
# 15/15 [==============================] - 3s 219ms/step - loss: 0.1853 - categorical_accuracy: 0.9359 - val_loss: 0.2989 - val_categorical_accuracy: 0.9104
# Epoch 23/60
# 15/15 [==============================] - 3s 220ms/step - loss: 0.1755 - categorical_accuracy: 0.9469 - val_loss: 0.2992 - val_categorical_accuracy: 0.9062
# Epoch 24/60
# 15/15 [==============================] - 3s 220ms/step - loss: 0.1848 - categorical_accuracy: 0.9420 - val_loss: 0.2932 - val_categorical_accuracy: 0.9000
# Epoch 25/60
# 15/15 [==============================] - 3s 219ms/step - loss: 0.1723 - categorical_accuracy: 0.9414 - val_loss: 0.2964 - val_categorical_accuracy: 0.9146
# Epoch 26/60
# 15/15 [==============================] - 3s 218ms/step - loss: 0.1706 - categorical_accuracy: 0.9460 - val_loss: 0.3050 - val_categorical_accuracy: 0.8958
# Epoch 27/60
# 15/15 [==============================] - 3s 218ms/step - loss: 0.1721 - categorical_accuracy: 0.9400 - val_loss: 0.2918 - val_categorical_accuracy: 0.9062
# Epoch 28/60
# 15/15 [==============================] - 3s 220ms/step - loss: 0.1454 - categorical_accuracy: 0.9569 - val_loss: 0.2887 - val_categorical_accuracy: 0.8979
# Epoch 29/60
# 15/15 [==============================] - 3s 219ms/step - loss: 0.1550 - categorical_accuracy: 0.9512 - val_loss: 0.3018 - val_categorical_accuracy: 0.8875
# Epoch 30/60
# 15/15 [==============================] - 3s 221ms/step - loss: 0.1488 - categorical_accuracy: 0.9529 - val_loss: 0.3112 - val_categorical_accuracy: 0.9042
# Epoch 31/60
# 15/15 [==============================] - 3s 221ms/step - loss: 0.1496 - categorical_accuracy: 0.9528 - val_loss: 0.2913 - val_categorical_accuracy: 0.9125
# Epoch 32/60
# 15/15 [==============================] - 3s 222ms/step - loss: 0.1326 - categorical_accuracy: 0.9568 - val_loss: 0.2983 - val_categorical_accuracy: 0.9104
# Epoch 33/60
# 15/15 [==============================] - 3s 220ms/step - loss: 0.1292 - categorical_accuracy: 0.9605 - val_loss: 0.2867 - val_categorical_accuracy: 0.9104
# Epoch 34/60
# 15/15 [==============================] - 3s 221ms/step - loss: 0.1219 - categorical_accuracy: 0.9626 - val_loss: 0.2855 - val_categorical_accuracy: 0.9146
# Epoch 35/60
# 15/15 [==============================] - 3s 221ms/step - loss: 0.1321 - categorical_accuracy: 0.9509 - val_loss: 0.2846 - val_categorical_accuracy: 0.9125
# Epoch 36/60
# 15/15 [==============================] - 3s 221ms/step - loss: 0.1224 - categorical_accuracy: 0.9636 - val_loss: 0.2873 - val_categorical_accuracy: 0.9146
# Epoch 37/60
# 15/15 [==============================] - 3s 221ms/step - loss: 0.1209 - categorical_accuracy: 0.9582 - val_loss: 0.2820 - val_categorical_accuracy: 0.9146
# Epoch 38/60
# 15/15 [==============================] - 3s 221ms/step - loss: 0.1265 - categorical_accuracy: 0.9579 - val_loss: 0.2947 - val_categorical_accuracy: 0.9000
# Epoch 39/60
# 15/15 [==============================] - 3s 222ms/step - loss: 0.1045 - categorical_accuracy: 0.9702 - val_loss: 0.2810 - val_categorical_accuracy: 0.9146
# Epoch 40/60
# 15/15 [==============================] - 3s 222ms/step - loss: 0.1010 - categorical_accuracy: 0.9661 - val_loss: 0.2917 - val_categorical_accuracy: 0.9125
# Epoch 41/60
# 15/15 [==============================] - 3s 219ms/step - loss: 0.1113 - categorical_accuracy: 0.9631 - val_loss: 0.2808 - val_categorical_accuracy: 0.9187
# Epoch 42/60
# 15/15 [==============================] - 3s 218ms/step - loss: 0.1101 - categorical_accuracy: 0.9601 - val_loss: 0.2861 - val_categorical_accuracy: 0.9083
# Epoch 43/60
# 15/15 [==============================] - 3s 218ms/step - loss: 0.1157 - categorical_accuracy: 0.9584 - val_loss: 0.2910 - val_categorical_accuracy: 0.9125
# Epoch 44/60
# 15/15 [==============================] - 3s 220ms/step - loss: 0.0903 - categorical_accuracy: 0.9720 - val_loss: 0.2841 - val_categorical_accuracy: 0.9167
# Epoch 45/60
# 15/15 [==============================] - 3s 222ms/step - loss: 0.1073 - categorical_accuracy: 0.9606 - val_loss: 0.2816 - val_categorical_accuracy: 0.9187
# Epoch 46/60
# 15/15 [==============================] - 3s 218ms/step - loss: 0.0956 - categorical_accuracy: 0.9693 - val_loss: 0.2910 - val_categorical_accuracy: 0.9062
# Epoch 47/60
# 15/15 [==============================] - 3s 217ms/step - loss: 0.0974 - categorical_accuracy: 0.9667 - val_loss: 0.2947 - val_categorical_accuracy: 0.9146
# Epoch 48/60
# 15/15 [==============================] - 3s 219ms/step - loss: 0.0911 - categorical_accuracy: 0.9706 - val_loss: 0.2852 - val_categorical_accuracy: 0.9187
# Epoch 49/60
# 15/15 [==============================] - 3s 221ms/step - loss: 0.0904 - categorical_accuracy: 0.9688 - val_loss: 0.2925 - val_categorical_accuracy: 0.9062
# Epoch 50/60
# 15/15 [==============================] - 3s 220ms/step - loss: 0.0861 - categorical_accuracy: 0.9680 - val_loss: 0.2866 - val_categorical_accuracy: 0.9125
# Epoch 51/60
# 15/15 [==============================] - 3s 219ms/step - loss: 0.0859 - categorical_accuracy: 0.9751 - val_loss: 0.2856 - val_categorical_accuracy: 0.9125
# Epoch 52/60
# 15/15 [==============================] - 3s 220ms/step - loss: 0.0771 - categorical_accuracy: 0.9779 - val_loss: 0.3021 - val_categorical_accuracy: 0.9104
# Epoch 53/60
# 15/15 [==============================] - 3s 219ms/step - loss: 0.0826 - categorical_accuracy: 0.9752 - val_loss: 0.2944 - val_categorical_accuracy: 0.9083
# Epoch 54/60
# 15/15 [==============================] - 3s 219ms/step - loss: 0.0778 - categorical_accuracy: 0.9772 - val_loss: 0.2945 - val_categorical_accuracy: 0.9146
# Epoch 55/60
# 15/15 [==============================] - 3s 220ms/step - loss: 0.0764 - categorical_accuracy: 0.9741 - val_loss: 0.2989 - val_categorical_accuracy: 0.9125
# Epoch 56/60
# 15/15 [==============================] - 3s 222ms/step - loss: 0.0779 - categorical_accuracy: 0.9763 - val_loss: 0.2983 - val_categorical_accuracy: 0.9083
# Epoch 57/60
# 15/15 [==============================] - 3s 219ms/step - loss: 0.0804 - categorical_accuracy: 0.9756 - val_loss: 0.3161 - val_categorical_accuracy: 0.9000
# Epoch 58/60
# 15/15 [==============================] - 3s 221ms/step - loss: 0.0929 - categorical_accuracy: 0.9677 - val_loss: 0.3016 - val_categorical_accuracy: 0.9125
# Epoch 59/60
# 15/15 [==============================] - 3s 222ms/step - loss: 0.0785 - categorical_accuracy: 0.9729 - val_loss: 0.3002 - val_categorical_accuracy: 0.9125
# Epoch 60/60
# 15/15 [==============================] - 3s 217ms/step - loss: 0.0670 - categorical_accuracy: 0.9794 - val_loss: 0.2988 - val_categorical_accuracy: 0.9146

# %% [markdown]
# ### Evaluate training process

# %%
# evaluating model using all data (not in batches)
val_loss, val_acc = model.evaluate(val_images, val_labels, verbose=2)

fig,ax = plt.subplots(nrows=2,ncols=1,figsize=(12,12))
fs_L, fs_M, fs_S = 18, 16, 14
ax[0].plot(history.history['categorical_accuracy'], label='train')
ax[0].plot(history.history['val_categorical_accuracy'], label='validation')
ax[0].set_xlabel('Epoch', fontsize=fs_M)
ax[0].set_ylabel('Accuracy', fontsize=fs_M)
ax[0].tick_params(axis='both', which='major', labelsize=fs_S)
ax[0].set_title('Final mean validation accuracy: {}'.format(val_acc), fontsize=fs_M)
ax[0].set_xticks(range(0,5))
ax[0].legend(loc='lower right', fontsize=fs_M)

ax[1].plot(history.history['loss'], label='train')
ax[1].plot(history.history['val_loss'], label='validation')
ax[1].set_xlabel('Epoch', fontsize=fs_M)
ax[1].set_ylabel('Loss', fontsize=fs_M)
ax[1].tick_params(axis='both', which='major', labelsize=fs_S)
ax[1].set_xticks(range(0,5))
ax[1].legend(loc='upper right', fontsize=fs_M)

plt.show()
# Out:
# 15/15 - 1s - loss: 0.2988 - categorical_accuracy: 0.9146

# %%
ypred_test = model.predict(test_images)
ypred_train = model.predict(train_images)

# %%
# Plotting the ROC curve, to test for overtaining and preformance
title = ['Ash','Pollen','Dust']
fig1, ax1 = plt.subplots(figsize=(10,30), nrows=3)

for i in range(num_classes):
    fpr,tpr, threshold =sklearn.metrics.roc_curve(test_labels[:,i],ypred_test[:,i])
    ax1[i].plot(fpr,tpr,'b', label='Test: ROC curve')

    fpr_train,tpr_train, threshold_train =sklearn.metrics.roc_curve(train_labels[:,i],ypred_train[:,i])
    ax1[i].plot(fpr_train,tpr_train,'r', label='Train: ROC curve')
    ax1[i].plot(np.linspace(0,1,100),np.linspace(0,1,100),'g', label='1:1 curve')
    ax1[i].set(xlabel='False positive rate',ylabel='True postive rate',title=title[i])
    ax1[i].legend()


    # The AUC and accuracy is computed and printed in the figure
    auc_score_train = auc(fpr_train,tpr_train)   
    auc_score_test = auc(fpr,tpr)   

    acc_score_train = accuracy_score(train_labels[:,i],np.where(ypred_train[:,i] > 0.5, 1, 0))
    acc_score_test = accuracy_score(test_labels[:,i],np.where(ypred_test[:,i] > 0.5, 1, 0))

    row_labels=['Test',
            'Train']
    table_vals=[[round(auc_score_test,5),round(acc_score_test,5)],
            [round(auc_score_train,5),round(acc_score_train,5)]]
    col_labels=['AUC','Accuracy']
    the_table = ax1[i].table(cellText=table_vals,
                  colWidths = [0.2]*3,
                  rowLabels=row_labels,
                  colLabels=col_labels,
                  loc='center right')

# %% [markdown]
# ### Inference

# %%
conf_matrix = tf.math.confusion_matrix(labels=np.argmax(test_labels, axis=1),
                                       predictions=np.argmax(ypred_test, axis = 1),
                                       num_classes=num_classes)
print('Confusion Matrix: ', conf_matrix)

# Original code:
#sess = tf.compat.v1.InteractiveSession()
#conf_matrix = confusion.eval(session=sess)     # Needs update to new TF...
#sess.close()

# Accuracy score for inference
error_rate = (np.sum(conf_matrix)-np.sum(np.diag(conf_matrix))) / np.sum(np.diag(conf_matrix))
inf_acc = 1-error_rate
print(error_rate)
print(inf_acc)
# Out:
# Confusion Matrix:  tf.Tensor(
# [[180  18  19]
#  [ 10 187   0]
#  [  6   0 180]], shape=(3, 3), dtype=int32)
# 0.09689213893967093
# 0.903107861060329

# %%
plt.figure(figsize=(10,5))
ax = sns.heatmap(conf_matrix, annot=True, annot_kws={"size": 16}, fmt="d", linewidths=.5, square=True, cbar=False, cmap='Greens')
ax.invert_yaxis()
plt.ylabel('Actual label', fontsize=16)
plt.xlabel('Predicted label', fontsize=16)
plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.title('Accuracy Score: {:.4f}'.format(inf_acc), fontsize=16)
plt.show()

print('Correct: {0}/{1}'.format(np.sum(np.diag(conf_matrix)),np.sum(conf_matrix)))
print('Wrong: {0}/{1}'.format((np.sum(conf_matrix)-np.sum(np.diag(conf_matrix))),np.sum(conf_matrix)))
# Out:
# Correct: 547/600
# Wrong: 53/600

# %% [markdown]
# ### Inspection of predictions

# %% [markdown]
# ##### Correctly predicted images

# %%
# show first 10 images that were correctly predicted
correct_idx = np.where(np.argmax(ypred_test, axis = 1) == np.argmax(test_labels, axis=1))[0]

fig, axs = plt.subplots(2,5, figsize=(15, 7))
axs = axs.ravel()
for i in range(10):
    axs[i].imshow(test_images[correct_idx[i],:,:,0], cmap=plt.cm.binary)
    axs[i].set_title('predicted: {} \n actual: {}'.format(np.argmax(ypred_test, axis = 1)[correct_idx[i]], np.argmax(test_labels, axis=1)[correct_idx[i]]), fontsize=18)
    axs[i].set_xticks([]); axs[i].set_yticks([]); axs[i].grid(False)

# %% [markdown]
# ##### Wrongly predicted images

# %%
# Show first 10 images that were wrongly predicted:
wrong_idx = np.where(np.argmax(ypred_test, axis = 1) != np.argmax(test_labels, axis=1))[0]

fig, axs = plt.subplots(2,5, figsize=(15, 7))
axs = axs.ravel()
for i in range(10):
    axs[i].imshow(test_images[wrong_idx[i],:,:,0], cmap=plt.cm.binary)
    axs[i].set_title('predicted: {} \n actual: {}'.format(np.argmax(ypred_test, axis = 1)[wrong_idx[i]], np.argmax(test_labels, axis=1)[wrong_idx[i]]), fontsize=18)
    axs[i].set_xticks([]); axs[i].set_yticks([]); axs[i].grid(False)

# %% [markdown]
# ### Baysian optimization

# %%
# Setting the model for baysian optimization

def create_model(filter_1=32, filter_2=64, drop_out = 0.40, nn1=164, lr=0.001 ):
  model = Sequential()
  model.add(Conv2D(filters=filter_1,
                 kernel_size=3,
                 strides=1,
                 padding='same',
                 activation='relu',
                 input_shape=(img_rows, img_cols, 1)))
  model.add(MaxPooling2D(pool_size=2, strides=None))

  model.add(Conv2D(filters=filter_2,
                 kernel_size=3,
                 strides=1,
                 padding='same',
                 activation='relu'))
  model.add(MaxPooling2D(pool_size=2, strides=None))

  
  model.add(Dropout(rate=drop_out))

  model.add(Flatten())


  model.add(Dense(units=nn1, activation='relu'))
  

  model.add(Dense(units=num_classes, activation='softmax'))
  model.compile(loss=categorical_crossentropy,
              optimizer=tf.keras.optimizers.Adam(learning_rate= lr),
              metrics=['categorical_accuracy'])    
  return model

# Setting up the optimization network used by the baysian optimization
def optimize_network(data, targets, data_val, targets_val,\
                    filter_1, filter_2, drop_out, nn1, lr):
    
    #Create the model using the specified hyperparameters.
    model = create_model(filter_1, filter_2, drop_out, nn1, lr)
    
    # Train the model with the train dataset.
    model.fit(data, targets, validation_data=(data_val, targets_val),
                    batch_size=64,
                    epochs=15)

    # Evaluate the model 
    score = model.evaluate(data_val, targets_val)
    print('Test loss:', score[0])
    print('Test categorical accuracy:', score[1])

    # Return the accuracy.

    return score[0]*-1

# %%
from bayes_opt import BayesianOptimization
# Set up the model, with the traning and validation data 
eval_network = lambda filter_1, filter_2, drop_out, nn1, lr: optimize_network(train_images,\
                    train_labels, val_images, val_labels,
                    int(filter_1), int(filter_2), drop_out, int(nn1), lr) 

# Bounded region of parameter space
pbounds = {'filter_1': (30,100), 'filter_2':(100,200),
           'drop_out':(0.2,0.6), 'nn1': (128,200), 'lr':(1e-6,1e-3) }


# Setup the baysian optimization
optimizer = BayesianOptimization(
    f=eval_network,
    pbounds=pbounds,
    verbose=1,  # verbose = 1 prints only when a maximum is observed, verbose = 0 is silent
    random_state=1,
)

# Preform the baysian optimization
start_time = time.time()
optimizer.maximize(init_points=5, n_iter=15,)
time_took = time.time() - start_time

print(f"Total runtime: {time_took}")
print(optimizer.max)
# Out:
# |   iter    |  target   | drop_out  | filter_1  | filter_2  |    lr     |    nn1    |
# -------------------------------------------------------------------------------------
# Epoch 1/15
# 30/30 [==============================] - 13s 313ms/step - loss: 2.5408 - categorical_accuracy: 0.5553 - val_loss: 0.4899 - val_categorical_accuracy: 0.8250
# Epoch 2/15
# 30/30 [==============================] - 8s 274ms/step - loss: 0.4160 - categorical_accuracy: 0.8531 - val_loss: 0.3407 - val_categorical_accuracy: 0.8583
# Epoch 3/15
# 30/30 [==============================] - 8s 273ms/step - loss: 0.2544 - categorical_accuracy: 0.8948 - val_loss: 0.2701 - val_categorical_accuracy: 0.8958
# Epoch 4/15
# 30/30 [==============================] - 8s 273ms/step - loss: 0.1904 - categorical_accuracy: 0.9407 - val_loss: 0.2346 - val_categorical_accuracy: 0.9146
# Epoch 5/15
# 30/30 [==============================] - 8s 273ms/step - loss: 0.1533 - categorical_accuracy: 0.9402 - val_loss: 0.2413 - val_categorical_accuracy: 0.9062
# Epoch 6/15
# 30/30 [==============================] - 8s 273ms/step - loss: 0.1277 - categorical_accuracy: 0.9589 - val_loss: 0.2737 - val_categorical_accuracy: 0.9083
# Epoch 7/15
# 30/30 [==============================] - 8s 274ms/step - loss: 0.1308 - categorical_accuracy: 0.9545 - val_loss: 0.3456 - val_categorical_accuracy: 0.8917
# Epoch 8/15
# 30/30 [==============================] - 8s 273ms/step - loss: 0.1413 - categorical_accuracy: 0.9439 - val_loss: 0.2639 - val_categorical_accuracy: 0.9187
# Epoch 9/15
# 30/30 [==============================] - 8s 272ms/step - loss: 0.0974 - categorical_accuracy: 0.9656 - val_loss: 0.2331 - val_categorical_accuracy: 0.9292
# Epoch 10/15
# 30/30 [==============================] - 8s 272ms/step - loss: 0.0924 - categorical_accuracy: 0.9679 - val_loss: 0.2666 - val_categorical_accuracy: 0.9146
# Epoch 11/15
# 30/30 [==============================] - 8s 273ms/step - loss: 0.0917 - categorical_accuracy: 0.9617 - val_loss: 0.2459 - val_categorical_accuracy: 0.9125
# Epoch 12/15
# 30/30 [==============================] - 8s 272ms/step - loss: 0.0665 - categorical_accuracy: 0.9738 - val_loss: 0.2348 - val_categorical_accuracy: 0.9229
# Epoch 13/15
# 30/30 [==============================] - 8s 273ms/step - loss: 0.0809 - categorical_accuracy: 0.9694 - val_loss: 0.2641 - val_categorical_accuracy: 0.9250
# Epoch 14/15
# 30/30 [==============================] - 8s 273ms/step - loss: 0.0504 - categorical_accuracy: 0.9823 - val_loss: 0.2758 - val_categorical_accuracy: 0.9167
# Epoch 15/15
# 30/30 [==============================] - 8s 272ms/step - loss: 0.0536 - categorical_accuracy: 0.9841 - val_loss: 0.2545 - val_categorical_accuracy: 0.9208
# 15/15 [==============================] - 1s 45ms/step - loss: 0.2545 - categorical_accuracy: 0.9208
# Test loss: 0.25445273518562317
# Test categorical accuracy: 0.9208333492279053
# Epoch 1/15
# 30/30 [==============================] - 11s 268ms/step - loss: 4.3146 - categorical_accuracy: 0.5467 - val_loss: 0.4583 - val_categorical_accuracy: 0.8146
# Epoch 2/15
# 30/30 [==============================] - 7s 229ms/step - loss: 0.3845 - categorical_accuracy: 0.8507 - val_loss: 0.3107 - val_categorical_accuracy: 0.8771
# Epoch 3/15
# 30/30 [==============================] - 7s 230ms/step - loss: 0.2248 - categorical_accuracy: 0.9106 - val_loss: 0.2506 - val_categorical_accuracy: 0.9125
# Epoch 4/15
# 30/30 [==============================] - 7s 231ms/step - loss: 0.1802 - categorical_accuracy: 0.9215 - val_loss: 0.2631 - val_categorical_accuracy: 0.9125
# Epoch 5/15
# 30/30 [==============================] - 7s 231ms/step - loss: 0.1393 - categorical_accuracy: 0.9518 - val_loss: 0.2418 - val_categorical_accuracy: 0.9250
# Epoch 6/15
# 30/30 [==============================] - 7s 230ms/step - loss: 0.1023 - categorical_accuracy: 0.9578 - val_loss: 0.2854 - val_categorical_accuracy: 0.9187
# Epoch 7/15
# 30/30 [==============================] - 7s 228ms/step - loss: 0.0791 - categorical_accuracy: 0.9744 - val_loss: 0.2741 - val_categorical_accuracy: 0.9187
# Epoch 8/15
# 30/30 [==============================] - 7s 228ms/step - loss: 0.0844 - categorical_accuracy: 0.9657 - val_loss: 0.2969 - val_categorical_accuracy: 0.9083
# Epoch 9/15
# 30/30 [==============================] - 7s 228ms/step - loss: 0.0718 - categorical_accuracy: 0.9740 - val_loss: 0.3522 - val_categorical_accuracy: 0.9062
# Epoch 10/15
# 30/30 [==============================] - 7s 227ms/step - loss: 0.0687 - categorical_accuracy: 0.9732 - val_loss: 0.3280 - val_categorical_accuracy: 0.9187
# Epoch 11/15
# 30/30 [==============================] - 7s 228ms/step - loss: 0.0411 - categorical_accuracy: 0.9832 - val_loss: 0.2944 - val_categorical_accuracy: 0.9292
# Epoch 12/15
# 30/30 [==============================] - 7s 228ms/step - loss: 0.0239 - categorical_accuracy: 0.9949 - val_loss: 0.3326 - val_categorical_accuracy: 0.9208
# Epoch 13/15
# 30/30 [==============================] - 7s 228ms/step - loss: 0.0234 - categorical_accuracy: 0.9946 - val_loss: 0.3200 - val_categorical_accuracy: 0.9146
# Epoch 14/15
# 30/30 [==============================] - 7s 229ms/step - loss: 0.0309 - categorical_accuracy: 0.9895 - val_loss: 0.3197 - val_categorical_accuracy: 0.9250
# Epoch 15/15
# 30/30 [==============================] - 7s 228ms/step - loss: 0.0206 - categorical_accuracy: 0.9928 - val_loss: 0.3660 - val_categorical_accuracy: 0.9146
# 15/15 [==============================] - 1s 37ms/step - loss: 0.3660 - categorical_accuracy: 0.9146
# Test loss: 0.3659667372703552
# Test categorical accuracy: 0.9145833253860474
# Epoch 1/15
# 30/30 [==============================] - 13s 326ms/step - loss: 7.7974 - categorical_accuracy: 0.5195 - val_loss: 0.4951 - val_categorical_accuracy: 0.7937
# Epoch 2/15
# 30/30 [==============================] - 8s 282ms/step - loss: 0.3648 - categorical_accuracy: 0.8502 - val_loss: 0.3292 - val_categorical_accuracy: 0.8875
# Epoch 3/15
# 30/30 [==============================] - 8s 282ms/step - loss: 0.2347 - categorical_accuracy: 0.9078 - val_loss: 0.2660 - val_categorical_accuracy: 0.9083
# Epoch 4/15
# 30/30 [==============================] - 8s 282ms/step - loss: 0.1634 - categorical_accuracy: 0.9368 - val_loss: 0.2881 - val_categorical_accuracy: 0.9062
# Epoch 5/15
# 30/30 [==============================] - 8s 280ms/step - loss: 0.1379 - categorical_accuracy: 0.9447 - val_loss: 0.2886 - val_categorical_accuracy: 0.9146
# Epoch 6/15
# 30/30 [==============================] - 8s 281ms/step - loss: 0.1258 - categorical_accuracy: 0.9459 - val_loss: 0.2883 - val_categorical_accuracy: 0.9062
# Epoch 7/15
# 30/30 [==============================] - 8s 282ms/step - loss: 0.0832 - categorical_accuracy: 0.9665 - val_loss: 0.2937 - val_categorical_accuracy: 0.9083
# Epoch 8/15
# 30/30 [==============================] - 8s 281ms/step - loss: 0.0653 - categorical_accuracy: 0.9750 - val_loss: 0.3053 - val_categorical_accuracy: 0.9125
# Epoch 9/15
# 30/30 [==============================] - 8s 282ms/step - loss: 0.0471 - categorical_accuracy: 0.9832 - val_loss: 0.3236 - val_categorical_accuracy: 0.9167
# Epoch 10/15
# 30/30 [==============================] - 8s 282ms/step - loss: 0.0335 - categorical_accuracy: 0.9916 - val_loss: 0.3322 - val_categorical_accuracy: 0.9187
# Epoch 11/15
# 30/30 [==============================] - 8s 282ms/step - loss: 0.0284 - categorical_accuracy: 0.9910 - val_loss: 0.3822 - val_categorical_accuracy: 0.9229
# Epoch 12/15
# 30/30 [==============================] - 8s 282ms/step - loss: 0.0377 - categorical_accuracy: 0.9856 - val_loss: 0.3758 - val_categorical_accuracy: 0.9167
# Epoch 13/15
# 30/30 [==============================] - 8s 281ms/step - loss: 0.0261 - categorical_accuracy: 0.9942 - val_loss: 0.4543 - val_categorical_accuracy: 0.8979
# Epoch 14/15
# 30/30 [==============================] - 8s 282ms/step - loss: 0.0157 - categorical_accuracy: 0.9939 - val_loss: 0.3882 - val_categorical_accuracy: 0.9167
# Epoch 15/15
# 30/30 [==============================] - 8s 281ms/step - loss: 0.0132 - categorical_accuracy: 0.9978 - val_loss: 0.4685 - val_categorical_accuracy: 0.9000
# 15/15 [==============================] - 1s 48ms/step - loss: 0.4685 - categorical_accuracy: 0.9000
# Test loss: 0.4685187339782715
# Test categorical accuracy: 0.8999999761581421
# Epoch 1/15
# 30/30 [==============================] - 13s 320ms/step - loss: 1.4081 - categorical_accuracy: 0.5714 - val_loss: 0.4247 - val_categorical_accuracy: 0.8354
# Epoch 2/15
# 30/30 [==============================] - 8s 281ms/step - loss: 0.3771 - categorical_accuracy: 0.8496 - val_loss: 0.3376 - val_categorical_accuracy: 0.8708
# Epoch 3/15
# 30/30 [==============================] - 8s 283ms/step - loss: 0.2357 - categorical_accuracy: 0.9189 - val_loss: 0.3051 - val_categorical_accuracy: 0.8875
# Epoch 4/15
# 30/30 [==============================] - 8s 284ms/step - loss: 0.1994 - categorical_accuracy: 0.9253 - val_loss: 0.3099 - val_categorical_accuracy: 0.8813
# Epoch 5/15
# 30/30 [==============================] - 8s 281ms/step - loss: 0.1739 - categorical_accuracy: 0.9383 - val_loss: 0.2411 - val_categorical_accuracy: 0.9187
# Epoch 6/15
# 30/30 [==============================] - 8s 281ms/step - loss: 0.1200 - categorical_accuracy: 0.9524 - val_loss: 0.2245 - val_categorical_accuracy: 0.9208
# Epoch 7/15
# 30/30 [==============================] - 8s 280ms/step - loss: 0.1102 - categorical_accuracy: 0.9602 - val_loss: 0.2574 - val_categorical_accuracy: 0.9229
# Epoch 8/15
# 30/30 [==============================] - 8s 279ms/step - loss: 0.0882 - categorical_accuracy: 0.9653 - val_loss: 0.2540 - val_categorical_accuracy: 0.9146
# Epoch 9/15
# 30/30 [==============================] - 8s 279ms/step - loss: 0.0958 - categorical_accuracy: 0.9690 - val_loss: 0.3445 - val_categorical_accuracy: 0.8917
# Epoch 10/15
# 30/30 [==============================] - 8s 279ms/step - loss: 0.0911 - categorical_accuracy: 0.9648 - val_loss: 0.2583 - val_categorical_accuracy: 0.9187
# Epoch 11/15
# 30/30 [==============================] - 8s 280ms/step - loss: 0.0625 - categorical_accuracy: 0.9759 - val_loss: 0.2472 - val_categorical_accuracy: 0.9271
# Epoch 12/15
# 30/30 [==============================] - 8s 281ms/step - loss: 0.0659 - categorical_accuracy: 0.9750 - val_loss: 0.2603 - val_categorical_accuracy: 0.9271
# Epoch 13/15
# 30/30 [==============================] - 8s 281ms/step - loss: 0.0739 - categorical_accuracy: 0.9690 - val_loss: 0.3397 - val_categorical_accuracy: 0.8896
# Epoch 14/15
# 30/30 [==============================] - 8s 281ms/step - loss: 0.0811 - categorical_accuracy: 0.9639 - val_loss: 0.2743 - val_categorical_accuracy: 0.9125
# Epoch 15/15
# 30/30 [==============================] - 8s 281ms/step - loss: 0.0421 - categorical_accuracy: 0.9888 - val_loss: 0.2704 - val_categorical_accuracy: 0.9271
# 15/15 [==============================] - 1s 42ms/step - loss: 0.2704 - categorical_accuracy: 0.9271
# Test loss: 0.2703854739665985
# Test categorical accuracy: 0.9270833134651184
# Epoch 1/15
# 30/30 [==============================] - 18s 441ms/step - loss: 4.4217 - categorical_accuracy: 0.5714 - val_loss: 0.4273 - val_categorical_accuracy: 0.8354
# Epoch 2/15
# 30/30 [==============================] - 11s 379ms/step - loss: 0.3127 - categorical_accuracy: 0.8708 - val_loss: 0.3064 - val_categorical_accuracy: 0.8875
# Epoch 3/15
# 30/30 [==============================] - 11s 380ms/step - loss: 0.2420 - categorical_accuracy: 0.9017 - val_loss: 0.2635 - val_categorical_accuracy: 0.9000
# Epoch 4/15
# 30/30 [==============================] - 11s 381ms/step - loss: 0.1615 - categorical_accuracy: 0.9375 - val_loss: 0.3672 - val_categorical_accuracy: 0.8604
# Epoch 5/15
# 30/30 [==============================] - 11s 382ms/step - loss: 0.1684 - categorical_accuracy: 0.9357 - val_loss: 0.2612 - val_categorical_accuracy: 0.9083
# Epoch 6/15
# 30/30 [==============================] - 11s 381ms/step - loss: 0.1442 - categorical_accuracy: 0.9321 - val_loss: 0.3180 - val_categorical_accuracy: 0.9000
# Epoch 7/15
# 30/30 [==============================] - 11s 382ms/step - loss: 0.1364 - categorical_accuracy: 0.9476 - val_loss: 0.3641 - val_categorical_accuracy: 0.8896
# Epoch 8/15
# 30/30 [==============================] - 11s 382ms/step - loss: 0.1021 - categorical_accuracy: 0.9686 - val_loss: 0.2764 - val_categorical_accuracy: 0.9083
# Epoch 9/15
# 30/30 [==============================] - 11s 381ms/step - loss: 0.0746 - categorical_accuracy: 0.9680 - val_loss: 0.2809 - val_categorical_accuracy: 0.9312
# Epoch 10/15
# 30/30 [==============================] - 11s 382ms/step - loss: 0.0505 - categorical_accuracy: 0.9798 - val_loss: 0.3514 - val_categorical_accuracy: 0.9083
# Epoch 11/15
# 30/30 [==============================] - 11s 381ms/step - loss: 0.0328 - categorical_accuracy: 0.9886 - val_loss: 0.2940 - val_categorical_accuracy: 0.9333
# Epoch 12/15
# 30/30 [==============================] - 11s 382ms/step - loss: 0.0330 - categorical_accuracy: 0.9884 - val_loss: 0.3461 - val_categorical_accuracy: 0.9146
# Epoch 13/15
# 30/30 [==============================] - 11s 381ms/step - loss: 0.0203 - categorical_accuracy: 0.9940 - val_loss: 0.3407 - val_categorical_accuracy: 0.9208
# Epoch 14/15
# 30/30 [==============================] - 11s 381ms/step - loss: 0.0196 - categorical_accuracy: 0.9943 - val_loss: 0.3436 - val_categorical_accuracy: 0.9312
# Epoch 15/15
# 30/30 [==============================] - 11s 381ms/step - loss: 0.0255 - categorical_accuracy: 0.9920 - val_loss: 0.3271 - val_categorical_accuracy: 0.9292
# 15/15 [==============================] - 1s 63ms/step - loss: 0.3271 - categorical_accuracy: 0.9292
# Test loss: 0.32707348465919495
# Test categorical accuracy: 0.9291666746139526
# Epoch 1/15
# 30/30 [==============================] - 11s 284ms/step - loss: 0.9272 - categorical_accuracy: 0.5355 - val_loss: 0.6425 - val_categorical_accuracy: 0.7688
# Epoch 2/15
# 30/30 [==============================] - 7s 247ms/step - loss: 0.5959 - categorical_accuracy: 0.7853 - val_loss: 0.5308 - val_categorical_accuracy: 0.8021
# Epoch 3/15
# 30/30 [==============================] - 8s 251ms/step - loss: 0.4998 - categorical_accuracy: 0.8195 - val_loss: 0.4880 - val_categorical_accuracy: 0.8146
# Epoch 4/15
# 30/30 [==============================] - 8s 252ms/step - loss: 0.4517 - categorical_accuracy: 0.8400 - val_loss: 0.4549 - val_categorical_accuracy: 0.8313
# Epoch 5/15
# 30/30 [==============================] - 7s 248ms/step - loss: 0.4348 - categorical_accuracy: 0.8408 - val_loss: 0.4353 - val_categorical_accuracy: 0.8333
# Epoch 6/15
# 30/30 [==============================] - 7s 246ms/step - loss: 0.4017 - categorical_accuracy: 0.8559 - val_loss: 0.4228 - val_categorical_accuracy: 0.8313
# Epoch 7/15
# 30/30 [==============================] - 7s 247ms/step - loss: 0.3947 - categorical_accuracy: 0.8490 - val_loss: 0.4135 - val_categorical_accuracy: 0.8313
# Epoch 8/15
# 30/30 [==============================] - 7s 244ms/step - loss: 0.3746 - categorical_accuracy: 0.8652 - val_loss: 0.4016 - val_categorical_accuracy: 0.8417
# Epoch 9/15
# 30/30 [==============================] - 7s 244ms/step - loss: 0.3579 - categorical_accuracy: 0.8739 - val_loss: 0.4014 - val_categorical_accuracy: 0.8438
# Epoch 10/15
# 30/30 [==============================] - 7s 244ms/step - loss: 0.3502 - categorical_accuracy: 0.8804 - val_loss: 0.3903 - val_categorical_accuracy: 0.8417
# Epoch 11/15
# 30/30 [==============================] - 7s 245ms/step - loss: 0.3464 - categorical_accuracy: 0.8747 - val_loss: 0.3809 - val_categorical_accuracy: 0.8500
# Epoch 12/15
# 30/30 [==============================] - 7s 245ms/step - loss: 0.3556 - categorical_accuracy: 0.8723 - val_loss: 0.3753 - val_categorical_accuracy: 0.8583
# Epoch 13/15
# 30/30 [==============================] - 7s 245ms/step - loss: 0.3168 - categorical_accuracy: 0.8964 - val_loss: 0.3647 - val_categorical_accuracy: 0.8729
# Epoch 14/15
# 30/30 [==============================] - 7s 248ms/step - loss: 0.3213 - categorical_accuracy: 0.8874 - val_loss: 0.3626 - val_categorical_accuracy: 0.8771
# Epoch 15/15
# 30/30 [==============================] - 7s 248ms/step - loss: 0.3232 - categorical_accuracy: 0.8807 - val_loss: 0.3614 - val_categorical_accuracy: 0.8729
# 15/15 [==============================] - 1s 36ms/step - loss: 0.3614 - categorical_accuracy: 0.8729
# Test loss: 0.3614438474178314
# Test categorical accuracy: 0.8729166388511658
# Epoch 1/15
# 30/30 [==============================] - 21s 597ms/step - loss: 0.9549 - categorical_accuracy: 0.5020 - val_loss: 0.7086 - val_categorical_accuracy: 0.7688
# Epoch 2/15
# 30/30 [==============================] - 16s 526ms/step - loss: 0.6640 - categorical_accuracy: 0.7973 - val_loss: 0.5811 - val_categorical_accuracy: 0.8104
# Epoch 3/15
# 30/30 [==============================] - 15s 517ms/step - loss: 0.5385 - categorical_accuracy: 0.8080 - val_loss: 0.5255 - val_categorical_accuracy: 0.8146
# Epoch 4/15
# 30/30 [==============================] - 15s 511ms/step - loss: 0.5023 - categorical_accuracy: 0.8205 - val_loss: 0.4883 - val_categorical_accuracy: 0.8146
# Epoch 5/15
# 30/30 [==============================] - 15s 510ms/step - loss: 0.4731 - categorical_accuracy: 0.8236 - val_loss: 0.4678 - val_categorical_accuracy: 0.8250
# Epoch 6/15
# 30/30 [==============================] - 15s 512ms/step - loss: 0.4325 - categorical_accuracy: 0.8504 - val_loss: 0.4458 - val_categorical_accuracy: 0.8292
# Epoch 7/15
# 30/30 [==============================] - 15s 517ms/step - loss: 0.4132 - categorical_accuracy: 0.8622 - val_loss: 0.4325 - val_categorical_accuracy: 0.8333
# Epoch 8/15
# 30/30 [==============================] - 16s 518ms/step - loss: 0.4111 - categorical_accuracy: 0.8606 - val_loss: 0.4169 - val_categorical_accuracy: 0.8375
# Epoch 9/15
# 30/30 [==============================] - 15s 516ms/step - loss: 0.3991 - categorical_accuracy: 0.8477 - val_loss: 0.4085 - val_categorical_accuracy: 0.8417
# Epoch 10/15
# 30/30 [==============================] - 15s 514ms/step - loss: 0.3860 - categorical_accuracy: 0.8592 - val_loss: 0.4000 - val_categorical_accuracy: 0.8479
# Epoch 11/15
# 30/30 [==============================] - 15s 515ms/step - loss: 0.3540 - categorical_accuracy: 0.8709 - val_loss: 0.3955 - val_categorical_accuracy: 0.8438
# Epoch 12/15
# 30/30 [==============================] - 15s 516ms/step - loss: 0.3495 - categorical_accuracy: 0.8757 - val_loss: 0.3888 - val_categorical_accuracy: 0.8542
# Epoch 13/15
# 30/30 [==============================] - 15s 515ms/step - loss: 0.3465 - categorical_accuracy: 0.8700 - val_loss: 0.3811 - val_categorical_accuracy: 0.8562
# Epoch 14/15
# 30/30 [==============================] - 15s 516ms/step - loss: 0.3208 - categorical_accuracy: 0.8910 - val_loss: 0.3773 - val_categorical_accuracy: 0.8583
# Epoch 15/15
# 30/30 [==============================] - 15s 515ms/step - loss: 0.3405 - categorical_accuracy: 0.8820 - val_loss: 0.3780 - val_categorical_accuracy: 0.8521
# 15/15 [==============================] - 2s 65ms/step - loss: 0.3780 - categorical_accuracy: 0.8521
# Test loss: 0.3779561221599579
# Test categorical accuracy: 0.8520833253860474
# Epoch 1/15
# 30/30 [==============================] - 13s 312ms/step - loss: 5.1905 - categorical_accuracy: 0.5567 - val_loss: 0.4627 - val_categorical_accuracy: 0.8354
# Epoch 2/15
# 30/30 [==============================] - 8s 272ms/step - loss: 0.3257 - categorical_accuracy: 0.8713 - val_loss: 0.3071 - val_categorical_accuracy: 0.8729
# Epoch 3/15
# 30/30 [==============================] - 8s 272ms/step - loss: 0.2219 - categorical_accuracy: 0.9077 - val_loss: 0.2797 - val_categorical_accuracy: 0.9125
# Epoch 4/15
# 30/30 [==============================] - 8s 272ms/step - loss: 0.1725 - categorical_accuracy: 0.9323 - val_loss: 0.2826 - val_categorical_accuracy: 0.9021
# Epoch 5/15
# 30/30 [==============================] - 8s 273ms/step - loss: 0.1637 - categorical_accuracy: 0.9362 - val_loss: 0.3374 - val_categorical_accuracy: 0.8687
# Epoch 6/15
# 30/30 [==============================] - 8s 274ms/step - loss: 0.1613 - categorical_accuracy: 0.9351 - val_loss: 0.2472 - val_categorical_accuracy: 0.9146
# Epoch 7/15
# 30/30 [==============================] - 8s 273ms/step - loss: 0.0969 - categorical_accuracy: 0.9677 - val_loss: 0.2774 - val_categorical_accuracy: 0.9146
# Epoch 8/15
# 30/30 [==============================] - 8s 272ms/step - loss: 0.0997 - categorical_accuracy: 0.9626 - val_loss: 0.3363 - val_categorical_accuracy: 0.8917
# Epoch 9/15
# 30/30 [==============================] - 8s 273ms/step - loss: 0.0872 - categorical_accuracy: 0.9694 - val_loss: 0.2691 - val_categorical_accuracy: 0.9292
# Epoch 10/15
# 30/30 [==============================] - 8s 272ms/step - loss: 0.0469 - categorical_accuracy: 0.9858 - val_loss: 0.2884 - val_categorical_accuracy: 0.9167
# Epoch 11/15
# 30/30 [==============================] - 8s 272ms/step - loss: 0.0447 - categorical_accuracy: 0.9827 - val_loss: 0.2897 - val_categorical_accuracy: 0.9229
# Epoch 12/15
# 30/30 [==============================] - 8s 272ms/step - loss: 0.0446 - categorical_accuracy: 0.9832 - val_loss: 0.3385 - val_categorical_accuracy: 0.8958
# Epoch 13/15
# 30/30 [==============================] - 8s 272ms/step - loss: 0.0546 - categorical_accuracy: 0.9784 - val_loss: 0.3149 - val_categorical_accuracy: 0.9125
# Epoch 14/15
# 30/30 [==============================] - 8s 273ms/step - loss: 0.0340 - categorical_accuracy: 0.9871 - val_loss: 0.3423 - val_categorical_accuracy: 0.9042
# Epoch 15/15
# 30/30 [==============================] - 8s 273ms/step - loss: 0.0245 - categorical_accuracy: 0.9936 - val_loss: 0.3919 - val_categorical_accuracy: 0.9104
# 15/15 [==============================] - 1s 47ms/step - loss: 0.3919 - categorical_accuracy: 0.9104
# Test loss: 0.39194315671920776
# Test categorical accuracy: 0.9104166626930237
# Epoch 1/15
# 30/30 [==============================] - 17s 542ms/step - loss: 0.9373 - categorical_accuracy: 0.5203 - val_loss: 0.6693 - val_categorical_accuracy: 0.7417
# Epoch 2/15
# 30/30 [==============================] - 16s 543ms/step - loss: 0.6044 - categorical_accuracy: 0.7857 - val_loss: 0.5470 - val_categorical_accuracy: 0.7958
# Epoch 3/15
# 30/30 [==============================] - 16s 540ms/step - loss: 0.5277 - categorical_accuracy: 0.7998 - val_loss: 0.4982 - val_categorical_accuracy: 0.8146
# Epoch 4/15
# 30/30 [==============================] - 16s 532ms/step - loss: 0.4682 - categorical_accuracy: 0.8275 - val_loss: 0.4646 - val_categorical_accuracy: 0.8333
# Epoch 5/15
# 30/30 [==============================] - 16s 529ms/step - loss: 0.4361 - categorical_accuracy: 0.8417 - val_loss: 0.4501 - val_categorical_accuracy: 0.8313
# Epoch 6/15
# 30/30 [==============================] - 16s 530ms/step - loss: 0.4250 - categorical_accuracy: 0.8490 - val_loss: 0.4263 - val_categorical_accuracy: 0.8354
# Epoch 7/15
# 30/30 [==============================] - 16s 535ms/step - loss: 0.3875 - categorical_accuracy: 0.8643 - val_loss: 0.4126 - val_categorical_accuracy: 0.8396
# Epoch 8/15
# 30/30 [==============================] - 16s 536ms/step - loss: 0.3783 - categorical_accuracy: 0.8614 - val_loss: 0.4063 - val_categorical_accuracy: 0.8583
# Epoch 9/15
# 30/30 [==============================] - 16s 534ms/step - loss: 0.3453 - categorical_accuracy: 0.8799 - val_loss: 0.3923 - val_categorical_accuracy: 0.8562
# Epoch 10/15
# 30/30 [==============================] - 16s 533ms/step - loss: 0.3521 - categorical_accuracy: 0.8737 - val_loss: 0.3873 - val_categorical_accuracy: 0.8479
# Epoch 11/15
# 30/30 [==============================] - 16s 533ms/step - loss: 0.3376 - categorical_accuracy: 0.8780 - val_loss: 0.3749 - val_categorical_accuracy: 0.8625
# Epoch 12/15
# 30/30 [==============================] - 16s 534ms/step - loss: 0.3141 - categorical_accuracy: 0.8891 - val_loss: 0.3723 - val_categorical_accuracy: 0.8708
# Epoch 13/15
# 30/30 [==============================] - 16s 534ms/step - loss: 0.3441 - categorical_accuracy: 0.8835 - val_loss: 0.3651 - val_categorical_accuracy: 0.8771
# Epoch 14/15
# 30/30 [==============================] - 16s 535ms/step - loss: 0.3042 - categorical_accuracy: 0.8966 - val_loss: 0.3639 - val_categorical_accuracy: 0.8646
# Epoch 15/15
# 30/30 [==============================] - 16s 534ms/step - loss: 0.3108 - categorical_accuracy: 0.8822 - val_loss: 0.3540 - val_categorical_accuracy: 0.8813
# 15/15 [==============================] - 1s 69ms/step - loss: 0.3540 - categorical_accuracy: 0.8813
# Test loss: 0.354017049074173
# Test categorical accuracy: 0.8812500238418579
# Epoch 1/15
# 30/30 [==============================] - 8s 245ms/step - loss: 0.9360 - categorical_accuracy: 0.6053 - val_loss: 0.6775 - val_categorical_accuracy: 0.7521
# Epoch 2/15
# 30/30 [==============================] - 7s 236ms/step - loss: 0.6242 - categorical_accuracy: 0.7950 - val_loss: 0.5652 - val_categorical_accuracy: 0.7917
# Epoch 3/15
# 30/30 [==============================] - 7s 238ms/step - loss: 0.5480 - categorical_accuracy: 0.8030 - val_loss: 0.5016 - val_categorical_accuracy: 0.8104
# Epoch 4/15
# 30/30 [==============================] - 7s 240ms/step - loss: 0.4796 - categorical_accuracy: 0.8218 - val_loss: 0.4814 - val_categorical_accuracy: 0.8083
# Epoch 5/15
# 30/30 [==============================] - 7s 240ms/step - loss: 0.4577 - categorical_accuracy: 0.8351 - val_loss: 0.4541 - val_categorical_accuracy: 0.8188
# Epoch 6/15
# 30/30 [==============================] - 7s 238ms/step - loss: 0.4194 - categorical_accuracy: 0.8502 - val_loss: 0.4388 - val_categorical_accuracy: 0.8396
# Epoch 7/15
# 30/30 [==============================] - 7s 237ms/step - loss: 0.3931 - categorical_accuracy: 0.8808 - val_loss: 0.4340 - val_categorical_accuracy: 0.8292
# Epoch 8/15
# 30/30 [==============================] - 7s 235ms/step - loss: 0.4071 - categorical_accuracy: 0.8578 - val_loss: 0.4193 - val_categorical_accuracy: 0.8250
# Epoch 9/15
# 30/30 [==============================] - 7s 234ms/step - loss: 0.3767 - categorical_accuracy: 0.8654 - val_loss: 0.4049 - val_categorical_accuracy: 0.8375
# Epoch 10/15
# 30/30 [==============================] - 7s 234ms/step - loss: 0.3581 - categorical_accuracy: 0.8716 - val_loss: 0.3980 - val_categorical_accuracy: 0.8417
# Epoch 11/15
# 30/30 [==============================] - 7s 234ms/step - loss: 0.3763 - categorical_accuracy: 0.8551 - val_loss: 0.3995 - val_categorical_accuracy: 0.8625
# Epoch 12/15
# 30/30 [==============================] - 7s 233ms/step - loss: 0.3504 - categorical_accuracy: 0.8721 - val_loss: 0.3859 - val_categorical_accuracy: 0.8479
# Epoch 13/15
# 30/30 [==============================] - 7s 234ms/step - loss: 0.3274 - categorical_accuracy: 0.8998 - val_loss: 0.3850 - val_categorical_accuracy: 0.8438
# Epoch 14/15
# 30/30 [==============================] - 7s 235ms/step - loss: 0.3213 - categorical_accuracy: 0.8894 - val_loss: 0.3736 - val_categorical_accuracy: 0.8542
# Epoch 15/15
# 30/30 [==============================] - 7s 236ms/step - loss: 0.3129 - categorical_accuracy: 0.8886 - val_loss: 0.3771 - val_categorical_accuracy: 0.8687
# 15/15 [==============================] - 1s 37ms/step - loss: 0.3771 - categorical_accuracy: 0.8687
# Test loss: 0.37713950872421265
# Test categorical accuracy: 0.8687499761581421
# Epoch 1/15
# 30/30 [==============================] - 8s 188ms/step - loss: 0.9354 - categorical_accuracy: 0.5270 - val_loss: 0.6780 - val_categorical_accuracy: 0.7479
# Epoch 2/15
# 30/30 [==============================] - 5s 176ms/step - loss: 0.6303 - categorical_accuracy: 0.7778 - val_loss: 0.5597 - val_categorical_accuracy: 0.7833
# Epoch 3/15
# 30/30 [==============================] - 5s 166ms/step - loss: 0.5218 - categorical_accuracy: 0.8156 - val_loss: 0.5081 - val_categorical_accuracy: 0.8104
# Epoch 4/15
# 30/30 [==============================] - 5s 168ms/step - loss: 0.4783 - categorical_accuracy: 0.8278 - val_loss: 0.4789 - val_categorical_accuracy: 0.8125
# Epoch 5/15
# 30/30 [==============================] - 5s 168ms/step - loss: 0.4394 - categorical_accuracy: 0.8468 - val_loss: 0.4579 - val_categorical_accuracy: 0.8271
# Epoch 6/15
# 30/30 [==============================] - 5s 167ms/step - loss: 0.4242 - categorical_accuracy: 0.8524 - val_loss: 0.4379 - val_categorical_accuracy: 0.8167
# Epoch 7/15
# 30/30 [==============================] - 5s 166ms/step - loss: 0.3927 - categorical_accuracy: 0.8723 - val_loss: 0.4245 - val_categorical_accuracy: 0.8208
# Epoch 8/15
# 30/30 [==============================] - 5s 166ms/step - loss: 0.3851 - categorical_accuracy: 0.8598 - val_loss: 0.4157 - val_categorical_accuracy: 0.8354
# Epoch 9/15
# 30/30 [==============================] - 5s 165ms/step - loss: 0.3720 - categorical_accuracy: 0.8728 - val_loss: 0.4115 - val_categorical_accuracy: 0.8500
# Epoch 10/15
# 30/30 [==============================] - 5s 165ms/step - loss: 0.3609 - categorical_accuracy: 0.8780 - val_loss: 0.3981 - val_categorical_accuracy: 0.8458
# Epoch 11/15
# 30/30 [==============================] - 5s 165ms/step - loss: 0.3606 - categorical_accuracy: 0.8674 - val_loss: 0.3931 - val_categorical_accuracy: 0.8438
# Epoch 12/15
# 30/30 [==============================] - 5s 165ms/step - loss: 0.3620 - categorical_accuracy: 0.8649 - val_loss: 0.3873 - val_categorical_accuracy: 0.8438
# Epoch 13/15
# 30/30 [==============================] - 5s 164ms/step - loss: 0.3332 - categorical_accuracy: 0.8779 - val_loss: 0.3819 - val_categorical_accuracy: 0.8438
# Epoch 14/15
# 30/30 [==============================] - 5s 165ms/step - loss: 0.3304 - categorical_accuracy: 0.8850 - val_loss: 0.3749 - val_categorical_accuracy: 0.8542
# Epoch 15/15
# 30/30 [==============================] - 5s 164ms/step - loss: 0.3267 - categorical_accuracy: 0.8864 - val_loss: 0.3704 - val_categorical_accuracy: 0.8583
# 15/15 [==============================] - 1s 29ms/step - loss: 0.3704 - categorical_accuracy: 0.8583
# Test loss: 0.3704078495502472
# Test categorical accuracy: 0.8583333492279053
# Epoch 1/15
# 30/30 [==============================] - 15s 424ms/step - loss: 1.7135 - categorical_accuracy: 0.6273 - val_loss: 0.4159 - val_categorical_accuracy: 0.8479
# Epoch 2/15
# 30/30 [==============================] - 11s 375ms/step - loss: 0.3597 - categorical_accuracy: 0.8607 - val_loss: 0.2809 - val_categorical_accuracy: 0.8813
# Epoch 3/15
# 30/30 [==============================] - 11s 378ms/step - loss: 0.2443 - categorical_accuracy: 0.9036 - val_loss: 0.3269 - val_categorical_accuracy: 0.8562
# Epoch 4/15
# 30/30 [==============================] - 11s 375ms/step - loss: 0.2160 - categorical_accuracy: 0.9128 - val_loss: 0.3808 - val_categorical_accuracy: 0.8625
# Epoch 5/15
# 30/30 [==============================] - 11s 372ms/step - loss: 0.1898 - categorical_accuracy: 0.9255 - val_loss: 0.2592 - val_categorical_accuracy: 0.9083
# Epoch 6/15
# 30/30 [==============================] - 11s 371ms/step - loss: 0.1178 - categorical_accuracy: 0.9510 - val_loss: 0.2638 - val_categorical_accuracy: 0.9146
# Epoch 7/15
# 30/30 [==============================] - 11s 370ms/step - loss: 0.0928 - categorical_accuracy: 0.9693 - val_loss: 0.2592 - val_categorical_accuracy: 0.9208
# Epoch 8/15
# 30/30 [==============================] - 11s 371ms/step - loss: 0.0726 - categorical_accuracy: 0.9727 - val_loss: 0.2374 - val_categorical_accuracy: 0.9187
# Epoch 9/15
# 30/30 [==============================] - 11s 373ms/step - loss: 0.0725 - categorical_accuracy: 0.9684 - val_loss: 0.2783 - val_categorical_accuracy: 0.9104
# Epoch 10/15
# 30/30 [==============================] - 11s 373ms/step - loss: 0.0621 - categorical_accuracy: 0.9765 - val_loss: 0.2950 - val_categorical_accuracy: 0.9187
# Epoch 11/15
# 30/30 [==============================] - 11s 373ms/step - loss: 0.0521 - categorical_accuracy: 0.9800 - val_loss: 0.2901 - val_categorical_accuracy: 0.9167
# Epoch 12/15
# 30/30 [==============================] - 11s 373ms/step - loss: 0.0402 - categorical_accuracy: 0.9877 - val_loss: 0.3259 - val_categorical_accuracy: 0.9167
# Epoch 13/15
# 30/30 [==============================] - 11s 373ms/step - loss: 0.0426 - categorical_accuracy: 0.9849 - val_loss: 0.3068 - val_categorical_accuracy: 0.9229
# Epoch 14/15
# 30/30 [==============================] - 11s 372ms/step - loss: 0.0338 - categorical_accuracy: 0.9883 - val_loss: 0.3064 - val_categorical_accuracy: 0.9125
# Epoch 15/15
# 30/30 [==============================] - 11s 372ms/step - loss: 0.0267 - categorical_accuracy: 0.9915 - val_loss: 0.3803 - val_categorical_accuracy: 0.9083
# 15/15 [==============================] - 1s 54ms/step - loss: 0.3803 - categorical_accuracy: 0.9083
# Test loss: 0.38030773401260376
# Test categorical accuracy: 0.9083333611488342
# Epoch 1/15
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/bayes_opt/target_space.py in probe(self, params)
#     190         try:
# --> 191             target = self._cache[_hashable(x)]
#     192         except KeyError:
#
# KeyError: (0.2, 100.0, 153.63398028120594, 1e-06, 151.4077030167009)
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-21-9506c1afbc68> in <module>()
#      19 # Preform the baysian optimization
#      20 start_time = time.time()
# ---> 21 optimizer.maximize(init_points=5, n_iter=15,)
#      22 time_took = time.time() - start_time
#      23
#
# /usr/local/lib/python3.7/dist-packages/bayes_opt/bayesian_optimization.py in maximize(self, init_points, n_iter, acq, kappa, kappa_decay, kappa_decay_delay, xi, **gp_params)
#     183                 iteration += 1
#     184
# --> 185             self.probe(x_probe, lazy=False)
#     186
#     187             if self._bounds_transformer:
#
# /usr/local/lib/python3.7/dist-packages/bayes_opt/bayesian_optimization.py in probe(self, params, lazy)
#     114             self._queue.add(params)
#     115         else:
# --> 116             self._space.probe(params)
#     117             self.dispatch(Events.OPTIMIZATION_STEP)
#     118
#
# /usr/local/lib/python3.7/dist-packages/bayes_opt/target_space.py in probe(self, params)
#     192         except KeyError:
#     193             params = dict(zip(self._keys, x))
# --> 194             target = self.target_func(**params)
#     195             self.register(x, target)
#     196         return target
#
# <ipython-input-21-9506c1afbc68> in <lambda>(filter_1, filter_2, drop_out, nn1, lr)
#       2 # Set up the model, with the traning and validation data
#       3 eval_network = lambda filter_1, filter_2, drop_out, nn1, lr: optimize_network(train_images,                    train_labels, val_images, val_labels,
# ----> 4                     int(filter_1), int(filter_2), drop_out, int(nn1), lr)
#       5
#       6 # Bounded region of parameter space
#
# <ipython-input-20-37c7848b7071> in optimize_network(data, targets, data_val, targets_val, filter_1, filter_2, drop_out, nn1, lr)
#      42     model.fit(data, targets, validation_data=(data_val, targets_val),
#      43                     batch_size=64,
# ---> 44                     epochs=15)
#      45
#      46     # Evaluate the model
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1156                 _r=1):
#    1157               callbacks.on_train_batch_begin(step)
# -> 1158               tmp_logs = self.train_function(iterator)
#    1159               if data_handler.should_sync:
#    1160                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     948         # Lifting succeeded, so variables are initialized and we can run the
#     949         # stateless function.
# --> 950         return self._stateless_fn(*args, **kwds)
#     951     else:
#     952       _, _, _, filtered_flat_args = \
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3023     return graph_function._call_flat(
# -> 3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#    3026   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1959       # No tape is watching; skip to running the function.
#    1960       return self._build_call_outputs(self._inference_function.call(
# -> 1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#    1963         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[9792,16384] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node gradient_tape/sequential_13/conv2d_27/BiasAdd/BiasAddGrad (defined at /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:774) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#  [Op:__inference_train_function_35385]
#
# Function call stack:
# train_function

# %%
# Setting up the found optimal parameters
params_BO = optimizer.max['params']
params_BO['nn1'] = int(params_BO['nn1'])
params_BO['filter_1'] = int(params_BO['filter_1'])
params_BO['filter_2'] = int(params_BO['filter_2'])
print(params_BO)

# %%
# create the neural network using the found optimal hyper parameters
model_BO = create_model(**params_BO)

start=datetime.now()
# Train the model using the traning and valdiation data set
history_BO = model_BO.fit(train_images, train_labels,
                    batch_size=62,
                    epochs=60,
                    verbose=1,
                    validation_data=(val_images, val_labels))
stop=datetime.now()
execution_time_NN = stop-start
print(execution_time_NN)

# %%
# evaluating model using all data (not in batches)
val_loss, val_acc = model_BO.evaluate(val_images, val_labels, verbose=2)

fig,ax = plt.subplots(nrows=2,ncols=1,figsize=(12,12))
fs_L, fs_M, fs_S = 18, 16, 14
ax[0].plot(history_BO.history['categorical_accuracy'], label='train')
ax[0].plot(history_BO.history['val_categorical_accuracy'], label='validation')
ax[0].set_xlabel('Epoch', fontsize=fs_M)
ax[0].set_ylabel('Accuracy', fontsize=fs_M)
ax[0].tick_params(axis='both', which='major', labelsize=fs_S)
ax[0].set_title('Final mean validation accuracy: {}'.format(val_acc), fontsize=fs_M)
ax[0].set_xticks(range(0,5))
ax[0].legend(loc='lower right', fontsize=fs_M)

ax[1].plot(history_BO.history['loss'], label='train')
ax[1].plot(history_BO.history['val_loss'], label='validation')
ax[1].set_xlabel('Epoch', fontsize=fs_M)
ax[1].set_ylabel('Loss', fontsize=fs_M)
ax[1].tick_params(axis='both', which='major', labelsize=fs_S)
ax[1].set_xticks(range(0,5))
ax[1].legend(loc='upper right', fontsize=fs_M)

plt.show()

# %%
ypred_test = model_BO.predict(test_images)
ypred_train = model_BO.predict(train_images)
# Plotting the ROC curve, to test for overtaining and preformance
title = ['Ash','Pollen','Dust']
fig1, ax1 = plt.subplots(figsize=(10,30), nrows=3)

for i in range(num_classes):
    fpr,tpr, threshold =sklearn.metrics.roc_curve(test_labels[:,i],ypred_test[:,i])
    ax1[i].plot(fpr,tpr,'b', label='Test: ROC curve')

    fpr_train,tpr_train, threshold_train =sklearn.metrics.roc_curve(train_labels[:,i],ypred_train[:,i])
    ax1[i].plot(fpr_train,tpr_train, 'r', label='Train: ROC curve')
    ax1[i].plot(np.linspace(0,1,100), np.linspace(0,1,100),'g', label='1:1 curve')
    ax1[i].set(xlabel='False positive rate', ylabel='True postive rate',title=title[i])
    ax1[i].legend()


    # The AUC and accuracy is computed and printed in the figure
    auc_score_train = auc(fpr_train,tpr_train)   
    auc_score_test = auc(fpr,tpr)   

    acc_score_train = accuracy_score(train_labels[:,i], np.where(ypred_train[:,i] > 0.5, 1, 0))
    acc_score_test = accuracy_score(test_labels[:,i], np.where(ypred_test[:,i] > 0.5, 1, 0))

    row_labels=['Test',
            'Train']
    table_vals=[[round(auc_score_test,5), round(acc_score_test,5)],
            [round(auc_score_train,5), round(acc_score_train,5)]]
    col_labels=['AUC','Accuracy']
    the_table = ax1[i].table(cellText=table_vals,
                  colWidths = [0.2]*3,
                  rowLabels=row_labels,
                  colLabels=col_labels,
                  loc='center right')

# %%
conf_matrix = tf.math.confusion_matrix(labels=np.argmax(test_labels, axis=1),
                                       predictions=np.argmax(ypred_test, axis = 1),
                                       num_classes=num_classes)
print('Confusion Matrix: ', conf_matrix)

# Original code:
#sess = tf.compat.v1.InteractiveSession()
#conf_matrix = confusion.eval(session=sess)     # Needs update to new TF...
#sess.close()

# Accuracy score for inference
error_rate = (np.sum(conf_matrix)-np.sum(np.diag(conf_matrix))) / np.sum(np.diag(conf_matrix))
inf_acc = 1-error_rate
plt.figure(figsize=(10,5))
ax = sns.heatmap(conf_matrix, annot=True, annot_kws={"size": 16}, fmt="d", linewidths=.5, square=True, cbar=False, cmap='Greens')
ax.invert_yaxis()
plt.ylabel('Actual label', fontsize=16)
plt.xlabel('Predicted label', fontsize=16)
plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.title('Accuracy Score: {:.4f}'.format(inf_acc), fontsize=16)
plt.show()

print('Correct: {0}/{1}'.format(np.sum(np.diag(conf_matrix)),np.sum(conf_matrix)))
print('Wrong: {0}/{1}'.format((np.sum(conf_matrix)-np.sum(np.diag(conf_matrix))),np.sum(conf_matrix)))
